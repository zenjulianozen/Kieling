# %% [markdown]
# ### 01 - E lá vamos nós!

# %% [markdown]
# Segundo projeto, eis o resultado: <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# O processo todo é bem simples, todo mundo que já fez painéis consegue formar um desses, ainda mais que quase todas as medidas foram aproveitadas do projeto anterior. <br>
# Então, sem demoras, seguem os processos de criação: <br>

# %% [markdown]
# Faturamento Mensal: <br>
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
# ![image-3.png](attachment:image-3.png) <br>

# %% [markdown]
# Meta de faturamento: <br>
# ![image.png](attachment:image.png) <br>
#
# ![image-2.png](attachment:image-2.png) <br>
#
# Criação da tabela de metas: <br>
# ![image-3.png](attachment:image-3.png) <br>
#
# Métrica de metas: <br>
# ![image-4.png](attachment:image-4.png) <br>
# ![image-5.png](attachment:image-5.png) <br>

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png) <br>

# %% [markdown]
# Variações de Margens: <br>
# ![image.png](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png) <br>
#
# ![image-4.png](attachment:image-4.png) <br>
# ![image-5.png](attachment:image-5.png) <br>
#
# ![image-6.png](attachment:image-6.png) <br>

# %% [markdown]
# ![image.png](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png) <br>
#
# ![image-3.png](attachment:image-3.png) <br>
# ![image-4.png](attachment:image-4.png) <br>
# ![image-5.png](attachment:image-5.png) <br>
# ![image-6.png](attachment:image-6.png) <br>
# ![image-7.png](attachment:image-7.png) <br>

# %% [markdown]
# ![image.png](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png) <br>
# ![image-3.png](attachment:image-3.png) <br>

# %% [markdown]
# ### 02 \o/

# %% [markdown]
# ![image.png](attachment:image.png) <br>
