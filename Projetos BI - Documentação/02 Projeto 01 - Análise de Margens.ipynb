# %% [markdown]
# ## Olá! <br>
#
# Bem vindo ao segmento que tratará de como o dashboard de Análise de Margens foi construído, desde o tratamento dos dados, até a apresentação deles
#
# Resultado final:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 01 - Importação, tratamento e transformação dos dados

# %% [markdown]
# Para este dashboard foram utilizadas duas bases de dados, já tratadas no segmento anterior: <br>
# 01 - 455_M <br>
# 02 - Complementos - Suzano <br>
#
# Vamos começar pela importação e transformação dos dados:
#
# Importação: <br>
# ![image.png](attachment:image.png) <br>
#
# Transformação: <br>
# ![image-2.png](attachment:image-2.png) <br>
# ![image-3.png](attachment:image-3.png) <br>
# Segue código das transformações apresentadas acima: <br>
# = Table.TransformColumnTypes(#"455 M_Sheet",{{"Column1", Int64.Type}, {"Column2", type text}, {"Column3", type text}, {"Column4", type text}, {"Column5", type any}, {"Column6", type text}, {"Column7", type text}, {"Column8", type text}, {"Column9", type any}, {"Column10", type any}, {"Column11", type any}, {"Column12", type any}, {"Column13", type text}, {"Column14", type text}, {"Column15", type text}, {"Column16", type text}, {"Column17", type text}, {"Column18", type text}, {"Column19", type text}, {"Column20", type text}, {"Column21", type text}, {"Column22", type text}, {"Column23", type text}, {"Column24", type text}, {"Column25", type text}, {"Column26", type text}, {"Column27", type text}, {"Column28", type text}, {"Column29", type text}, {"Column30", type text}, {"Column31", type text}, {"Column32", type text}, {"Column33", type text}, {"Column34", type text}, {"Column35", type text}, {"Column36", type text}, {"Column37", type text}, {"Column38", type text}, {"Column39", type text}, {"Column40", type text}, {"Column41", type text}, {"Column42", type text}, {"Column43", type text}, {"Column44", type text}, {"Column45", type text}, {"Column46", type text}, {"Column47", type text}, {"Column48", type text}, {"Column49", type text}, {"Column50", type text}, {"Column51", type text}, {"Column52", type text}, {"Column53", type text}, {"Column54", type text}, {"Column55", type text}, {"Column56", type text}, {"Column57", type text}, {"Column58", type any}, {"Column59", type any}, {"Column60", type any}, {"Column61", type any}, {"Column62", type text}, {"Column63", type text}, {"Column64", type any}, {"Column65", type any}, {"Column66", type text}, {"Column67", type text}, {"Column68", type any}, {"Column69", type text}, {"Column70", type text}, {"Column71", type any}, {"Column72", type any}, {"Column73", type any}, {"Column74", type any}, {"Column75", type any}, {"Column76", type any}, {"Column77", type any}, {"Column78", type text}, {"Column79", type text}, {"Column80", type text}, {"Column81", type any}, {"Column82", type any}, {"Column83", type any}, {"Column84", type any}, {"Column85", type any}, {"Column86", type any}, {"Column87", type any}, {"Column88", type any}, {"Column89", type any}, {"Column90", type any}, {"Column91", type any}, {"Column92", type any}, {"Column93", type any}, {"Column94", type any}, {"Column95", type any}, {"Column96", type any}, {"Column97", type any}, {"Column98", type any}, {"Column99", type any}, {"Column100", type any}, {"Column101", type text}, {"Column102", type text}, {"Column103", type text}, {"Column104", type text}, {"Column105", type text}, {"Column106", type text}, {"Column107", type text}, {"Column108", type text}, {"Column109", type text}, {"Column110", type any}, {"Column111", type text}, {"Column112", type text}, {"Column113", type any}, {"Column114", type any}, {"Column115", type any}, {"Column116", type any}, {"Column117", type any}, {"Column118", type any}, {"Column119", type text}, {"Column120", type text}, {"Column121", type text}, {"Column122", type text}, {"Column123", type text}, {"Column124", type any}, {"Column125", type text}, {"Column126", type text}, {"Column127", type any}, {"Column128", type any}, {"Column129", type any}, {"Column130", type any}, {"Column131", type any}, {"Column132", type any}, {"Column133", type any}, {"Column134", type any}, {"Column135", type any}, {"Column136", type any}, {"Column137", type any}, {"Column138", type any}, {"Column139", type any}, {"Column140", type any}, {"Column141", type any}, {"Column142", type any}, {"Column143", type any}, {"Column144", type text}, {"Column145", type any}, {"Column146", type any}, {"Column147", type any}, {"Column148", type any}, {"Column149", type text}, {"Column150", type any}, {"Column151", type text}, {"Column152", type any}, {"Column153", type text}, {"Column154", type text}, {"Column155", type text}, {"Column156", type text}, {"Column157", type text}, {"Column158", type text}, {"Column159", type text}, {"Column160", type text}, {"Column161", type text}, {"Column162", type text}, {"Column163", type text}, {"Column164", type text}, {"Column165", type text}, {"Column166", type text}, {"Column167", type text}, {"Column168", type text}, {"Column169", type any}, {"Column170", type text}, {"Column171", type text}, {"Column172", type text}, {"Column173", type any}}) <br>
#
# ![image-4.png](attachment:image-4.png) <br>
# ![image-5.png](attachment:image-5.png) <br>
# Segue código das transformações acima: <br>
# = Table.TransformColumnTypes(#"Cabeçalhos Promovidos",{{"Número CT-e", type text}, {"Data de Emissao", type date}, {"Hora de Emissao", type time}, {"Data de Autorizacao", type date}, {"Hora de Autorizacao", type time}, {"Numero de Controle", type text}, {"Chave CT-e", type text}, {"CNPJ Remetente", type text}, {"Peso Real em Kg", type number}, {"Cubagem em m3", type number}, {"Quantidade de Volumes", Int64.Type}, {"Quantidade de Pares", Int64.Type}, {"Data da Liquidacao", type date}, {"Valor Liquidado", type number}, {"Valor da Mercadoria", type number}, {"Valor do Frete", type number}, {"Valor do Frete sem ICMS", type number}, {"Base de Calculo", type number}, {"Valor do ICMS", type number}, {"Aliquota", Percentage.Type}, {"Valor do ISS", type number}, {"Peso Calculado em Kg", type number}, {"Frete Peso", type number}, {"Frete Valor", type number}, {"Despacho", type number}, {"CAT", type number}, {"ITR", type number}, {"GRIS", type number}, {"Pedagio", type number}, {"TAS", type number}, {"TDA", type number}, {"Suframa", type number}, {"Dev Canhoto NF", type number}, {"Reembolso", type number}, {"Outros", type number}, {"Coleta", type number}, {"TDC", type number}, {"TAR", type number}, {"TDE", type number}, {"TRT", type number}, {"POS", type number}, {"Adicional de Frete", type number}, {"Imposto Repassado", type number}, {"Frete NTC", type number}, {"Frete Entrega", type number}, {"Separacao", type number}, {"Capatazia", type number}, {"Veiculo Dedicado", type number}, {"Paletizacao", type number}, {"Data de Inclusao da Fatura", type date}, {"Data do Vencimento", type date}, {"Valor da Fatura", type number}, {"Data da Liquidacao Fatura", type date}, {"Valor Liquidacao Fatura", type number}, {"Pgto Parcial", type number}, {"Result Com FRETE", type number}, {"Result Com DESPESAS", type number}, {"Result Com SEGURO", type number}, {"Result Com ICMS", type number}, {"Result Com PIS/COFINS", type number}, {"Result Com GRIS", type number}, {"Result Com PEDAGIO", type number}, {"Result Com EXPEDICAO", type number}, {"Result Com TRANFERENCIA", type number}, {"Result Com TRANSBORDO", type number}, {"Result Com VENDEDOR", type number}, {"Result Com RECEPCAO", type number}, {"Result Com DESPESAS DIV", type number}, {"Result Com R$", type number}, {"Result Com %", type number}, {"Resultado Minimo %", type number}, {"Resultado Real PEDAGIO", type number}, {"Resultado Real TRANFERENCIA", type number}, {"Resultado Real R$", type number}, {"Resultado Real %", type number}, {"Distancia em Km", type number}, {"Previsao de Entrega", type date}, {"Data da Entrega Realizada", type date}, {"Quantidade de Dias de Atraso", Int64.Type}, {"Compl Suzano - Diferença", type number}}) <br>
#
# ![image-6.png](attachment:image-6.png) <br>
# ![image-7.png](attachment:image-7.png) <br>
# ![image-8.png](attachment:image-8.png) <br>
# ![image-9.png](attachment:image-9.png) <br>
# ![image-10.png](attachment:image-10.png) <br>
# ![image-11.png](attachment:image-11.png) <br>
# ![image-12.png](attachment:image-12.png) <br>
# ![image-13.png](attachment:image-13.png) <br>
# ![image-14.png](attachment:image-14.png) <br>
# ![image-15.png](attachment:image-15.png) <br>

# %% [markdown]
# ### 02 - Criação do painel de Análise de Margens:

# %% [markdown]
# 01 - Começando por algo simples, os cards de informações chaves: <br>
# ![image-3.png](attachment:image-3.png) <br>
#
# Nº de CTRCs: <br>
# ![image.png](attachment:image.png) <br>
#
# Faturamento: <br>
# ![image-2.png](attachment:image-2.png) <br>
#
# Margem Bruta: <br>
# ![image-4.png](attachment:image-4.png) <br>
#
# % da mergem bruta: Primeiras medidas:<br>
# ![image-6.png](attachment:image-6.png)<br>
# ![image-7.png](attachment:image-7.png)<br>
#
# Cálculo das medidas: <br>
# ![image-5.png](attachment:image-5.png)<br>

# %% [markdown]
# 02 - Quadro de margens: <br>
# ![image.png](attachment:image.png) <br>
#
# Elementos de Texto: <br>
# ![image-2.png](attachment:image-2.png) <br>
#
#
# Elementos em cards: <br>
#
# Criação de uma coluna de classificação: <br>
# ![image-13.png](attachment:image-13.png) <br>
#
# Abaixo de 0: <br>
# ![image-3.png](attachment:image-3.png) <br>
#
# ![image-4.png](attachment:image-4.png) <br>
#
# ![image-5.png](attachment:image-5.png) <br>
#
# De 0 a 29,9%: <br>
# ![image-6.png](attachment:image-6.png) <br>
#
# ![image-7.png](attachment:image-7.png) <br>
#
# ![image-8.png](attachment:image-8.png) <br>
#
# De 30% a 49,9%: <br>
# ![image-9.png](attachment:image-9.png) <br>
#
# ![image-10.png](attachment:image-10.png) <br>
#
# ![image-11.png](attachment:image-11.png) <br>
#
# De 50% a 60%: <br>
# ![image-12.png](attachment:image-12.png) <br>
#
# ![image-14.png](attachment:image-14.png) <br>
#
# ![image-15.png](attachment:image-15.png) <br>
#
# De 60% em diante: <br>
# ![image-16.png](attachment:image-16.png) <br>
#
# ![image-17.png](attachment:image-17.png) <br>
#
# ![image-18.png](attachment:image-18.png) <br>

# %% [markdown]
# 03 - Quados de dados:
#
# Por Clientes: <br>
# ![image.png](attachment:image.png) <br>
#
# Linhas: <br>
# ![image-2.png](attachment:image-2.png) <br>
#
# Colunas: <br>
# Nada :D <br>
#
# Valores: <br>
# ![image-3.png](attachment:image-3.png) <br>
#
#
# Por UF: <br>
# ![image-4.png](attachment:image-4.png) <br>
#
# Linhas: <br>
# ![image-5.png](attachment:image-5.png) <br>
#
# Colunas: <br>
# Necas :P <br>
#
# Valores: <br>
# ![image-6.png](attachment:image-6.png) <br>

# %% [markdown]
# 04 - Segmentações e Filtros: <br>
#
# ![image.png](attachment:image.png)<br>
# ![image-2.png](attachment:image-2.png) <br>
#
# ***-------------------------------------------------------------------------------------------------------------------------------------------***
#
# ![image-3.png](attachment:image-3.png) <br>
# ![image-4.png](attachment:image-4.png) <br>
#
# ![image-5.png](attachment:image-5.png) <BR>
# ![image-6.png](attachment:image-6.png) <br>
#
# ![image-7.png](attachment:image-7.png) <br>
# ![image-8.png](attachment:image-8.png) <br>

# %% [markdown]
# ### 03 - \o/

# %% [markdown]
# ![image-2.png](attachment:image-2.png)<br>
#
# I can't die, I'm TOO BUSY FOR THAT!! <BR>
# ![image.png](attachment:image.png)
